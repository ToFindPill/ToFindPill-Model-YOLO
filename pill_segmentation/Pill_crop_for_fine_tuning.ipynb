# %%
# Fine-Tuning 위한 데이터 crop 코드

# %%
import torch
import cv2
from pathlib import Path
import matplotlib.pyplot as plt
import shutil

# 모델 로드
model_weights_path = '/data_2/ace_jungmin/yolov5/runs/train/yolov5_finetune/weights/last.pt'
model = torch.hub.load('/data_2/ace_jungmin/yolov5', 'custom', path=model_weights_path, source='local')  # 파인튜닝한 가중치 사용

# 탐지 설정 조정
model.conf = 0.05  # confidence threshold
model.iou = 0.5  # IoU threshold

# 이미지가 있는 상위 폴더 경로
img_base_folder_path = Path('/home/ace_jungmin/jupyter_notebook/pill_segmentation/pill')

# 결과를 저장할 상위 폴더 경로
output_base_dir = Path('output/fine_tuning_data')

# 모든 jpg 파일에 대해 탐지 수행
for img_path in img_base_folder_path.rglob('*.jpg'):
    # 이미지 로드
    img = cv2.imread(str(img_path))

    if img is None:
        print(f"이미지를 로드할 수 없습니다: {img_path}")
        continue

    # 이미지 크기 조정 및 모델에 맞게 전처리
    results = model(img)

    # 이미지가 속해있던 폴더의 구조를 유지하면서 새로운 폴더 생성
    relative_path = img_path.relative_to(img_base_folder_path)
    output_dir = output_base_dir / relative_path.parent
    output_dir.mkdir(parents=True, exist_ok=True)

    # 원본 이미지 저장
    #shutil.copy(str(img_path), output_dir / f'original_image_{img_path.stem}.png')

    # 원본 이미지를 복사하여 결과를 그릴 준비
    img_with_boxes = img.copy()

    # bounding box 기반 이미지 자르기 및 저장
    cropped_images = []
    for i, bbox in enumerate(results.xyxy):
        for j, detection in enumerate(bbox):
            x1, y1, x2, y2, conf, cls = detection
            x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])

            # bounding box 그리기
            cv2.rectangle(img_with_boxes, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # 약 이미지 자르기
            crop_img = img[y1:y2, x1:x2]
            cropped_images.append(crop_img)

            # 잘라낸 이미지 저장
            crop_img_path = output_dir / f'drug_{img_path.stem}_{i}_{j}.png'
            cv2.imwrite(str(crop_img_path), crop_img)

    # 원본 이미지와 탐지된 bounding box가 추가된 이미지 저장
    #output_image_path = output_dir / f'image_with_boxes_{img_path.stem}.png'
    #cv2.imwrite(str(output_image_path), img_with_boxes)

    print(f"이미지 {img_path.stem}에서 {len(cropped_images)}개의 객체를 탐지하였으며, 잘라낸 이미지를 {output_dir}에 저장했습니다.")

    print(results.xyxy)
# Out:
# requirements: Ultralytics requirement ['requests>=2.32.0'] not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v7.0-317-g00403794 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# 이미지 KakaoTalk_20240607_175425515_08에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.14007e+03, 1.56614e+03, 1.78457e+03, 2.34792e+03, 2.70520e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.28994e+03, 1.14628e+03, 2.19294e+03, 2.28584e+03, 2.19013e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_07에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.13750e+03, 1.87616e+03, 1.84394e+03, 2.61254e+03, 2.74198e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_05에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[8.84684e+02, 2.05294e+03, 1.81730e+03, 2.72861e+03, 2.42727e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_01에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[9.09630e+02, 1.61044e+03, 1.98876e+03, 2.55743e+03, 2.64069e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_06에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.34125e+03, 1.72408e+03, 2.24637e+03, 2.42607e+03, 2.46002e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_02에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.00119e+03, 1.71096e+03, 2.03575e+03, 2.44196e+03, 2.51671e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_09에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.17285e+03, 2.20471e+03, 2.04513e+03, 3.17299e+03, 2.56542e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_04에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.45949e+03, 1.68423e+03, 2.31975e+03, 2.45407e+03, 2.55771e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_07에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[1.00119e+03, 1.71096e+03, 2.03575e+03, 2.44196e+03, 2.51671e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_03에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-024603에 저장했습니다.
# [tensor([[9.97593e+02, 1.66946e+03, 1.93424e+03, 2.36611e+03, 2.53872e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_16에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.17745e+03, 1.96820e+03, 2.25281e+03, 2.83334e+03, 2.50218e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_13에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.11882e+03, 1.95638e+03, 2.18251e+03, 2.69222e+03, 2.32146e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_20에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.00381e+03, 1.80663e+03, 1.99185e+03, 2.50134e+03, 2.29688e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_26에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.46162e+03, 1.40173e+03, 2.63678e+03, 2.39045e+03, 2.71421e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_19에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[9.37195e+02, 1.80233e+03, 1.81843e+03, 2.78806e+03, 2.67646e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_27에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.12377e+03, 1.72183e+03, 2.14316e+03, 2.68213e+03, 2.21584e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_14에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.28481e+03, 2.02547e+03, 2.47651e+03, 2.77809e+03, 2.69603e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_24에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[9.89780e+02, 1.60653e+03, 2.21758e+03, 2.43442e+03, 2.23074e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_17에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.10882e+03, 1.51503e+03, 2.24112e+03, 2.24775e+03, 2.67390e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_15에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.08533e+03, 1.51168e+03, 2.13128e+03, 2.53341e+03, 2.74127e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_25에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.18005e+03, 1.10260e+03, 2.15130e+03, 2.22753e+03, 2.44683e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_21에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[1.07540e+03, 1.88763e+03, 2.27625e+03, 2.66891e+03, 2.59648e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_23에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[8.56843e+02, 1.76933e+03, 2.10104e+03, 2.70170e+03, 2.44545e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_18에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[6.43710e+02, 1.69009e+03, 1.73905e+03, 2.41846e+03, 2.25905e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_22에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033623에 저장했습니다.
# [tensor([[9.55759e+02, 1.21246e+03, 2.19789e+03, 2.31776e+03, 2.33245e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_10에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[7.70296e+02, 1.27671e+03, 1.59359e+03, 2.09663e+03, 2.64140e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_18에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[9.11765e+02, 1.53766e+03, 1.85871e+03, 2.47212e+03, 2.38137e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_11에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[1.49240e+03, 1.83095e+03, 2.28199e+03, 2.54943e+03, 2.81961e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_09에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[1.29643e+03, 1.78944e+03, 2.00840e+03, 2.47174e+03, 2.79403e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_14에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[8.41035e+02, 1.34196e+03, 1.75328e+03, 2.23652e+03, 2.70565e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_13에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[9.98952e+02, 1.65257e+03, 1.82070e+03, 2.44776e+03, 2.70767e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_15에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[1.14965e+03, 1.65652e+03, 1.97001e+03, 2.48470e+03, 2.64168e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_16에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[1.23425e+03, 2.22772e+03, 2.00382e+03, 2.95037e+03, 2.63082e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_12에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[1.07998e+03, 1.54054e+03, 1.96717e+03, 2.36733e+03, 2.62445e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_19에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[1.20368e+03, 1.60912e+03, 2.18357e+03, 2.52897e+03, 2.67482e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_17에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-000573에 저장했습니다.
# [tensor([[9.99636e+02, 1.95122e+03, 1.93699e+03, 2.87018e+03, 2.48764e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_19에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[5.02296e+02, 1.50885e+03, 1.58068e+03, 2.45967e+03, 2.43301e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_18에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[1.10971e+03, 1.55047e+03, 2.24379e+03, 2.06941e+03, 2.63166e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_12에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[1.16370e+03, 1.83950e+03, 2.45318e+03, 2.74050e+03, 2.42990e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_14에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[1.00296e+03, 1.91997e+03, 2.19089e+03, 2.39218e+03, 2.36190e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_11에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[9.38061e+02, 1.85524e+03, 2.26191e+03, 2.42755e+03, 2.34653e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_15에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[8.47934e+02, 1.58654e+03, 2.01374e+03, 2.37350e+03, 2.38815e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_13에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[1.16223e+03, 1.15398e+03, 2.27187e+03, 2.27822e+03, 2.37046e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_10에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[8.95911e+02, 1.66802e+03, 2.28241e+03, 2.54639e+03, 2.38369e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_16에서 2개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[1.04969e+03, 1.17403e+03, 2.07479e+03, 2.07473e+03, 2.41115e-01, 0.00000e+00],
#         [1.01469e+02, 1.60988e+02, 2.02698e+03, 2.17274e+03, 1.14011e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175425515_17에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-037941에 저장했습니다.
# [tensor([[6.90121e+02, 1.38964e+03, 2.00853e+03, 1.95722e+03, 2.66045e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_06에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[7.67499e+02, 1.23529e+03, 2.30059e+03, 2.35489e+03, 2.43122e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_02에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[9.81757e+02, 1.92142e+03, 2.51416e+03, 2.56369e+03, 1.78988e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_05에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[9.79508e+02, 1.52695e+03, 2.44764e+03, 2.50361e+03, 2.55145e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_03에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[4.96736e+02, 1.58274e+03, 1.92188e+03, 2.53553e+03, 1.91673e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_04에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[7.51403e+02, 1.31669e+03, 2.13047e+03, 2.29491e+03, 2.09332e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_07에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[9.72407e+02, 1.48356e+03, 2.12573e+03, 3.16190e+03, 2.64863e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[7.98514e+02, 1.46612e+03, 2.35350e+03, 2.10966e+03, 1.61065e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_01에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[1.17215e+03, 1.02772e+03, 2.15409e+03, 2.60590e+03, 1.79609e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_08에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-011441에 저장했습니다.
# [tensor([[1.21884e+03, 1.22287e+03, 1.86489e+03, 2.40571e+03, 2.39656e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_06에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[5.17934e+02, 1.64948e+03, 1.25467e+03, 2.75483e+03, 2.61052e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_04에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.11023e+03, 1.59760e+03, 2.09361e+03, 2.30209e+03, 2.48584e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_10에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.38878e+03, 1.61922e+03, 2.28813e+03, 2.73756e+03, 2.66013e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_12에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[8.75394e+02, 1.35465e+03, 2.06672e+03, 2.24453e+03, 2.74560e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_08에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.22859e+03, 1.51843e+03, 2.27791e+03, 2.31990e+03, 2.59753e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_02에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.41400e+03, 9.99310e+02, 2.15392e+03, 1.89641e+03, 2.55737e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.17131e+03, 1.79373e+03, 2.20925e+03, 2.46463e+03, 2.39381e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_05에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.07668e+03, 1.76673e+03, 2.09938e+03, 2.46072e+03, 2.35215e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_11에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.31729e+03, 1.60284e+03, 2.56340e+03, 2.39693e+03, 2.46403e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_03에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.09026e+03, 1.58931e+03, 2.05203e+03, 2.45648e+03, 2.60690e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_07에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.25914e+03, 1.72162e+03, 2.07547e+03, 2.67346e+03, 2.81135e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_09에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.21933e+03, 1.85087e+03, 1.90696e+03, 2.90143e+03, 2.59377e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175526981_01에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-030590에 저장했습니다.
# [tensor([[1.22186e+03, 1.13173e+03, 1.96901e+03, 2.21380e+03, 2.60457e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_02에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[8.56013e+02, 1.71823e+03, 1.83417e+03, 2.43344e+03, 2.60681e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_11에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.27037e+03, 1.39955e+03, 2.32309e+03, 2.37739e+03, 2.77484e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_08에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[9.08662e+02, 1.49822e+03, 1.91450e+03, 2.59191e+03, 2.40086e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_01에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.19502e+03, 1.73094e+03, 2.20237e+03, 2.49675e+03, 2.37318e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_06에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[9.58898e+02, 1.50561e+03, 1.99156e+03, 2.25284e+03, 2.55108e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_09에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.24402e+03, 1.82156e+03, 2.23638e+03, 2.72351e+03, 2.58711e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_03에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.07847e+03, 1.54335e+03, 2.11346e+03, 2.34799e+03, 2.48612e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.27178e+03, 1.51788e+03, 2.20987e+03, 2.43337e+03, 2.60459e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_05에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[8.83278e+02, 1.55258e+03, 1.94525e+03, 2.40493e+03, 2.41438e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_12에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.07742e+03, 1.63032e+03, 2.12773e+03, 2.42839e+03, 2.30199e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_04에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.27627e+03, 1.62575e+03, 2.29101e+03, 2.52216e+03, 2.30422e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175600495_10에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-033615에 저장했습니다.
# [tensor([[1.13759e+03, 2.00642e+03, 2.13238e+03, 2.76779e+03, 2.29550e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_21에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[9.96643e+02, 1.67602e+03, 2.49716e+03, 2.58458e+03, 2.37359e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_24에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[7.03197e+02, 2.01573e+03, 2.13579e+03, 2.80390e+03, 2.05024e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_26에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[1.15158e+03, 1.49513e+03, 2.49746e+03, 2.26080e+03, 1.77016e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_25에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[8.55099e+02, 1.72537e+03, 2.27064e+03, 2.27529e+03, 1.88116e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_28에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[1.06829e+03, 1.50872e+03, 2.16903e+03, 2.44984e+03, 2.37798e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_20에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[7.90896e+02, 1.29030e+03, 2.10990e+03, 2.59876e+03, 2.09924e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_23에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[1.16497e+03, 1.34375e+03, 2.32022e+03, 2.55675e+03, 2.60746e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_27에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[1.10929e+03, 1.68142e+03, 2.10943e+03, 2.59260e+03, 2.59833e-01, 0.00000e+00]], device='cuda:0')]
# 이미지 KakaoTalk_20240607_175239337_22에서 1개의 객체를 탐지하였으며, 잘라낸 이미지를 output/fine_tuning_data/K-025090에 저장했습니다.
# [tensor([[5.62093e+02, 1.53198e+03, 1.69837e+03, 2.39872e+03, 2.41863e-01, 0.00000e+00]], device='cuda:0')]
